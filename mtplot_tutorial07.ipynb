# %%
import matplotlib.pyplot as plt
import numpy as np


student1_age=np.random.randint(18,45 , (100))
student2_age=np.random.randint(15,40 , (100))

print(student1_age)
print(student2_age)
# Out:
# [41 41 31 43 19 35 44 26 21 25 34 39 35 44 36 41 36 41 25 25 22 37 22 44
#  23 40 18 43 35 27 40 40 23 28 35 27 39 30 21 41 44 30 32 34 18 39 44 37
#  25 40 30 37 21 37 37 25 18 35 41 21 18 34 23 22 34 44 44 31 19 19 21 19
#  35 31 24 31 20 30 34 19 37 27 43 37 32 31 26 30 26 42 42 40 38 29 36 27
#  18 43 43 34]
# [28 38 23 36 24 20 28 38 29 26 34 23 27 38 16 35 39 24 28 15 36 39 24 30
#  30 31 39 35 31 23 25 19 30 37 31 22 39 26 19 20 24 38 21 36 29 21 17 21
#  32 17 38 20 29 22 33 34 34 29 24 17 28 35 29 23 28 36 32 24 24 23 34 17
#  15 23 29 22 18 17 37 24 28 21 23 19 26 17 21 28 16 23 28 19 30 27 29 31
#  15 15 31 22]

# %%
plt.hist(student1_age)
# Out:
# (array([11., 11.,  6.,  8.,  6.,  7., 15.,  8., 14., 14.]),
#  array([18. , 20.6, 23.2, 25.8, 28.4, 31. , 33.6, 36.2, 38.8, 41.4, 44. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### we will see sum histogram arguments

# %% [markdown]
# plt.hist(
#     x,
#     bins=None,
#     range=None,
#     density=False,
#     weights=None,
#     cumulative=False,
#     bottom=None,
#     histtype='bar',
#     align='mid',
#     orientation='vertical',
#     rwidth=None,
#     log=False,
#     color=None,
#     label=None,
#     stacked=False,
#     *,
#     data=None,
#     **kwargs,
# )

# %%
plt.hist(student1_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95)
# Out:
# (array([10., 13., 14., 18., 20., 25.]),
#  array([15, 20, 25, 30, 35, 40, 45]),
#  <BarContainer object of 6 artists>)

# %%
plt.hist(student1_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color="g")
# Out:
# (array([10., 13., 14., 18., 20., 25.]),
#  array([15, 20, 25, 30, 35, 40, 45]),
#  <BarContainer object of 6 artists>)

# %%
plt.hist(student1_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color="g")
plt.hist(student2_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color="y")
# Out:
# (array([17., 28., 21., 16., 18.,  0.]),
#  array([15, 20, 25, 30, 35, 40, 45]),
#  <BarContainer object of 6 artists>)

# %%
# plt.hist(student1_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color="g")
# plt.hist(student2_age , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color="y")

# we will plot this in single line
plt.hist([student1_age,student2_age] , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color=["g","y"])
# Out:
# (array([[10., 13., 14., 18., 20., 25.],
#         [17., 28., 21., 16., 18.,  0.]]),
#  array([15, 20, 25, 30, 35, 40, 45]),
#  <a list of 2 BarContainer objects>)

# %%
plt.title("Students Age Data")
plt.xlabel("Students age" ,fontsize=15)
plt.ylabel("No of Students",fontsize=15)
plt.hist([student1_age,student2_age] , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color=["g","y"] , label=["student1_age","student2_age"])


plt.legend(shadow=True)
plt.show()

# %%
plt.figure(figsize=(16,9)) #to increase the image size
plt.title("Students Age Data")
plt.xlabel("Students age" ,fontsize=15)
plt.ylabel("No of Students",fontsize=15)
plt.hist([student1_age,student2_age] , bins=[15,20,25,30,35,40,45] ,rwidth=0.95 ,color=["g","y"] , label=["student1_age","student2_age"])


plt.legend(shadow=True)
plt.show()

# %%
plt.title("Students Age Data")
plt.xlabel("Students age" ,fontsize=15)
plt.ylabel("No of Students",fontsize=15)
plt.hist([student1_age,student2_age] , bins=[15,20,25,30,35,40,45] ,
         rwidth=0.95 ,color=["g","y"] , label=["student1_age","student2_age"], orientation='horizontal')


plt.legend(shadow=True)
plt.show()
